# %%
import random

def fitness(individual):
    ones = individual.count('1')
    if ones == 50:
        return 80
    else:
        return 80 - abs(50 - ones)

# %%
population_size = 300
chromosome_length = 80

def generate_individual():
    return ''.join(random.choice(['0', '1']) for _ in range(chromosome_length))

population = [generate_individual() for _ in range(population_size)]

# %%
def selection(pop):
    selected = []
    for _ in range(len(pop)):
        a = random.choice(pop)
        b = random.choice(pop)
        selected.append(a if fitness(a) > fitness(b) else b)
    return selected

# %%
def crossover(p1, p2):
    point = random.randint(1, chromosome_length - 1)
    c1 = p1[:point] + p2[point:]
    c2 = p2[:point] + p1[point:]
    return c1, c2

# %%
mutation_rate = 0.01

def mutate(ind):
    bits = []
    for b in ind:
        if random.random() < mutation_rate:
            bits.append('0' if b == '1' else '1')
        else:
            bits.append(b)
    return ''.join(bits)

# %%
generations = 50

for g in range(generations):
    selected = selection(population)
    next_population = []

    for i in range(0, population_size, 2):
        p1 = selected[i]
        p2 = selected[i+1]
        c1, c2 = crossover(p1, p2)
        next_population.append(mutate(c1))
        next_population.append(mutate(c2))
    
    population = next_population

    best = max(population, key=fitness)
    print(f"Generation {g+1}: Best Fitness = {fitness(best)}")
# Out:
# Generation 1: Best Fitness = 80
# Generation 2: Best Fitness = 80
# Generation 3: Best Fitness = 80
# Generation 4: Best Fitness = 80
# Generation 5: Best Fitness = 80
# Generation 6: Best Fitness = 80
# Generation 7: Best Fitness = 80
# Generation 8: Best Fitness = 80
# Generation 9: Best Fitness = 80
# Generation 10: Best Fitness = 80
# Generation 11: Best Fitness = 80
# Generation 12: Best Fitness = 80
# Generation 13: Best Fitness = 80
# Generation 14: Best Fitness = 80
# Generation 15: Best Fitness = 80
# Generation 16: Best Fitness = 80
# Generation 17: Best Fitness = 80
# Generation 18: Best Fitness = 80
# Generation 19: Best Fitness = 80
# Generation 20: Best Fitness = 80
# Generation 21: Best Fitness = 80
# Generation 22: Best Fitness = 80
# Generation 23: Best Fitness = 80
# Generation 24: Best Fitness = 80
# Generation 25: Best Fitness = 80
# Generation 26: Best Fitness = 80
# Generation 27: Best Fitness = 80
# Generation 28: Best Fitness = 80
# Generation 29: Best Fitness = 80
# Generation 30: Best Fitness = 80
# Generation 31: Best Fitness = 80
# Generation 32: Best Fitness = 80
# Generation 33: Best Fitness = 80
# Generation 34: Best Fitness = 80
# Generation 35: Best Fitness = 80
# Generation 36: Best Fitness = 80
# Generation 37: Best Fitness = 80
# Generation 38: Best Fitness = 80
# Generation 39: Best Fitness = 80
# Generation 40: Best Fitness = 80
# Generation 41: Best Fitness = 80
# Generation 42: Best Fitness = 80
# Generation 43: Best Fitness = 80
# Generation 44: Best Fitness = 80
# Generation 45: Best Fitness = 80
# Generation 46: Best Fitness = 80
# Generation 47: Best Fitness = 80
# Generation 48: Best Fitness = 80
# Generation 49: Best Fitness = 80
# Generation 50: Best Fitness = 80

# %%
best = max(population, key=fitness)
print("Best Individual:", best)
print("Number of Ones:", best.count('1'))
print("Final Fitness:", fitness(best))
# Out:
# Best Individual: 10110011101011100010110111101101011000011011111010110101011101101001111111101100
# Number of Ones: 50
# Final Fitness: 80
